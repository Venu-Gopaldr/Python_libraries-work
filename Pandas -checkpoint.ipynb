# %% [markdown]
# # Pandas

# %% [markdown]
# -pandas is an open source data analysis library written in python.
#
# -It leverages the power and speed of numpy to make data analysis and preprocessing easy for data scientists.
#
# -It provides rich and highly robust data operations.

# %% [markdown]
# # pandas data structure

# %% [markdown]
# pandas has two types of data structures:
#     a)Series - it's a one dimensional array with indexes,it stores a single column or row of data in a Dataframe.
#
#     b)Dataframe - it's a tabular spreadsheet like structure representing rows each of which contains one or multiple columns.
#
# -A one-dimensional array(labeled) capable of holding any type of data-Series
#
# -Antwo-dimensional data (labeled) structure with columns of potentially different types of data -DataFrame

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {"name": ['venu','bhooma','aishu','lalitha','rudramuni'],
       "marks":[92,72,84,63,87],
        "city":['dvg','klgt','bnglr','hlkt','sokke']
       }

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#         name  marks   city
# 0       venu     92    dvg
# 1     bhooma     72   klgt
# 2      aishu     84  bnglr
# 3    lalitha     63   hlkt
# 4  rudramuni     87  sokke

# %%
df.head(2)
# Out:
#      name  marks  city
# 0    venu     92   dvg
# 1  bhooma     72  klgt

# %%
df.tail(2)
# Out:
#         name  marks   city
# 3    lalitha     63   hlkt
# 4  rudramuni     87  sokke

# %%
df.describe() #statistical analysis
# Out:
#           marks
# count   5.00000
# mean   79.60000
# std    11.84483
# min    63.00000
# 25%    72.00000
# 50%    84.00000
# 75%    87.00000
# max    92.00000

# %%
df.to_csv('family.csv')  #converting dataframe into csv files

# %%
df.to_csv('family_without_index.csv',index = False)

# %%
df.shape
# Out:
# (5, 3)

# %%
#df.groupby('marks').name

# %%
df.rename({'name':'NAME','marks':'MARK','city':'CITY'},axis='columns')
# Out:
#         NAME  MARK   CITY
# 0       venu    92    dvg
# 1     bhooma    72   klgt
# 2      aishu    84  bnglr
# 3    lalitha    63   hlkt
# 4  rudramuni    87  sokke

# %%
venu = pd.read_csv('harry.csv')

# %%
venu
# Out:
#    Train no  speed   city
# 0     56778     92    dvg
# 1     87666     72   klgt
# 2     98755     84  bnglr
# 3     98666     63   hlkt
# 4     35677     87  sokke

# %%
venu['speed']
# Out:
# 0    92
# 1    72
# 2    84
# 3    63
# 4    87
# Name: speed, dtype: int64

# %%
venu['speed'][0]
# Out:
# 92

# %%
venu['speed'][0] = 50
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12176\1272940649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   venu['speed'][0] = 50

# %%
venu
# Out:
#    Train no  speed   city
# 0     56778     50    dvg
# 1     87666     72   klgt
# 2     98755     84  bnglr
# 3     98666     63   hlkt
# 4     35677     87  sokke

# %%
venu.to_csv('harry.csv')

# %%
venu.index = ['first', 'second', 'third', 'fourth','fifth']

# %%
venu
# Out:
#         Train no  speed   city
# first      56778     50    dvg
# second     87666     72   klgt
# third      98755     84  bnglr
# fourth     98666     63   hlkt
# fifth      35677     87  sokke

# %%
import pandas as pd
bhoom = pd.read_csv('C:/Users/User/Downloads/big_mart_sales.csv')

# %%
bhoom
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
bhoom.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
bhoom.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8513                Meat   99.9042            OUT035
# 8514              Canned   57.5904            OUT045
# 8515        Baking Goods  157.5288            OUT018
# ...

# %%
bhoom.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
bhoom.shape
# Out:
# (8523, 12)

# %%
import pandas as pd
b = pd.read_csv('C:/Users/User/Downloads/IRIS.csv')

# %%
b
# Out:
#     5.1  0.222222222  3.5     0.625  1.4  0.06779661  0.2  0.041666667  \
# 0   4.9     0.166667  3.0  0.416667  1.4    0.067797  0.2     0.041667
# 1   4.7     0.111111  3.2  0.500000  1.3    0.050847  0.2     0.041667
# 2   4.6     0.083333  3.1  0.458333  1.5    0.084746  0.2     0.041667
# 3   5.0     0.194444  3.6  0.666667  1.4    0.067797  0.2     0.041667
# 4   5.4     0.305556  3.9  0.791667  1.7    0.118644  0.4     0.125000
# ..  ...          ...  ...       ...  ...         ...  ...          ...
# 94  7.2     0.805556  3.0  0.416667  5.8    0.813559  1.6     0.625000
# 95  7.4     0.861111  2.8  0.333333  6.1    0.864407  1.9     0.750000
# 96  7.9     0.999900  3.8  0.750000  6.4    0.915254  2.0     0.791667
# 97  6.4     0.583333  2.8  0.333333  5.6    0.779661  2.2     0.875000
# 98  6.3     0.555556  2.8  0.333333  5.1    0.694915  1.5     0.583333
#
#        setosa
# 0      setosa
# 1      setosa
# 2      setosa
# 3      setosa
# 4      setosa
# ..        ...
# ...

# %%
b.head(1)
# Out:
#    5.1  0.222222222  3.5     0.625  1.4  0.06779661  0.2  0.041666667  setosa
# 0  4.9     0.166667  3.0  0.416667  1.4    0.067797  0.2     0.041667  setosa

# %%
b.tail(2)
# Out:
#     5.1  0.222222222  3.5     0.625  1.4  0.06779661  0.2  0.041666667  \
# 97  6.4     0.583333  2.8  0.333333  5.6    0.779661  2.2     0.875000
# 98  6.3     0.555556  2.8  0.333333  5.1    0.694915  1.5     0.583333
#
#        setosa
# 97  virginica
# 98  virginica

# %%
b.describe()
# Out:
#              5.1  0.222222222        3.5      0.625        1.4  0.06779661  \
# count  99.000000    99.000000  99.000000  99.000000  99.000000   99.000000
# mean    5.922222     0.450717   3.036364   0.431918   3.875758    0.487517
# std     0.856852     0.237821   0.439261   0.182784   1.777127    0.301043
# min     4.300000     0.010000   2.000000   0.010000   1.000000    0.010000
# 25%     5.200000     0.250000   2.800000   0.333333   1.600000    0.101695
# 50%     5.900000     0.444444   3.000000   0.416667   4.500000    0.593220
# 75%     6.500000     0.611111   3.300000   0.541667   5.100000    0.694915
# max     7.900000     0.999900   4.400000   0.999900   6.900000    0.999900
#
#              0.2  0.041666667
# count  99.000000    99.000000
# mean    1.223232     0.468314
# std     0.742284     0.308823
# min     0.100000     0.010000
# 25%     0.400000     0.125000
# 50%     1.400000     0.541667
# 75%     1.800000     0.708333
# max     2.500000     0.999900

# %%
b.shape
# Out:
# (99, 9)

# %% [markdown]
# # PANDAS DATA STRUCTURE

# %% [markdown]
# pandas has two types of data structure
#     -a)Series - it's a one dimensional array with indexes,t stores a single column or row of data in a dataframe
#     -b)Dataframe - it's a tabular spreadsheet like structure representing rows each of whichh contains one or multple columns
#
# --a one-dimensional array(labelled) capable of holding any type of data - Series
# --a two-dimensional data(labelled) structure with columns of potentially different types of data - DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
vg = pd.Series(np.random.rand(32))

# %%
vg
# Out:
# 0     0.901054
# 1     0.840991
# 2     0.348925
# 3     0.362204
# 4     0.843915
# 5     0.506195
# 6     0.098878
# 7     0.540914
# 8     0.669900
# 9     0.638918
# 10    0.050284
# 11    0.677242
# 12    0.941703
# 13    0.483475
# 14    0.777696
# 15    0.748240
# 16    0.859964
# 17    0.642123
# 18    0.963486
# 19    0.181027
# 20    0.567454
# 21    0.129403
# 22    0.008087
# 23    0.468711
# 24    0.936458
# 25    0.847684
# 26    0.661917
# 27    0.524097
# 28    0.326945
# 29    0.189392
# 30    0.833397
# 31    0.090700
# dtype: float64

# %%
type(vg)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
import numpy as np
newdf = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0
rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E
# 3    0.119814  0.589312  0.221551  0.372581  0.134815
# 9    0.256538  0.106204  0.121250  0.852306  0.902344
# 18   0.120844  0.436861  0.307980  0.120990  0.808307
# 20   0.231809  0.343417  0.683826  0.963463  0.509861
# 33   0.244464  0.706890  0.484865  0.614630  0.061179
# ..        ...       ...       ...       ...       ...
# 306  0.206374  0.669962  0.834762  0.154458  0.801728
# 316  0.134947  0.473761  0.116591  0.593917  0.306160
# 319  0.000128  0.624222  0.107520  0.157195  0.746275
# 322  0.026858  0.560776  0.516174  0.773665  0.036731
# 327  0.106991  0.571738  0.620325  0.851151  0.019317
#
# [86 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0       666  0.519559  0.912975  0.534882  0.343862
# 1  0.974342  0.233653  0.408505  0.104467  0.001949

# %%
newdf.iloc[0,4]  #when we want to count using indexes u can use iloc if u are using name of the row or column then u can use loc
# Out:
# 0.3438621687186384

# %%
newdf.iloc[[0,4],[1,2]]
# Out:
#           B         C
# 0  0.519559  0.912975
# 4  0.357449  0.472451

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.974342  0.233653  0.408505  0.104467  0.001949
# 2    0.414918  0.539039  0.674943  0.602984  0.045261
# 3    0.119814  0.589312  0.221551  0.372581  0.134815
# 4    0.942015  0.357449  0.472451  0.085514  0.155223
# 5    0.599654  0.069481  0.838729  0.172616  0.221483
# ..        ...       ...       ...       ...       ...
# 329  0.445246  0.205417  0.320015  0.162270  0.414028
# 330  0.409597  0.743952  0.571884  0.646609  0.290460
# 331  0.632856  0.767467  0.378673  0.507562  0.432620
# 332  0.382705  0.039203  0.604431  0.775401  0.812413
# 333  0.824661  0.579149  0.701643  0.175579  0.088738
#
# [333 rows x 5 columns]

# %%
newdf.drop(['A','C'],axis=1)
# Out:
#             B         D         E
# 0    0.519559  0.534882  0.343862
# 1    0.233653  0.104467  0.001949
# 2    0.539039  0.602984  0.045261
# 3    0.589312  0.372581  0.134815
# 4    0.357449  0.085514  0.155223
# ..        ...       ...       ...
# 329  0.205417  0.162270  0.414028
# 330  0.743952  0.646609  0.290460
# 331  0.767467  0.507562  0.432620
# 332  0.039203  0.775401  0.812413
# 333  0.579149  0.175579  0.088738
#
# [334 rows x 3 columns]

# %%
newdf.drop([7, 8], axis=0, inplace=True)

# %%
newdf.head(9)
# Out:
#            A         B         C         D         E
# 0        666  0.519559  0.912975  0.534882  0.343862
# 3   0.119814  0.589312  0.221551  0.372581  0.134815
# 4   0.942015  0.357449  0.472451  0.085514  0.155223
# 5   0.599654  0.069481  0.838729  0.172616  0.221483
# 6   0.700728  0.100798  0.435555  0.384188  0.770515
# 9   0.256538  0.106204  0.121250  0.852306  0.902344
# 10  0.702225  0.434970  0.143104  0.933943  0.890712
# 11  0.378849  0.307907  0.872345  0.889683  0.999243
# 12  0.961805  0.600590  0.334162  0.889749  0.914945

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         666  0.519559  0.912975  0.534882  0.343862
# 3    0.119814  0.589312  0.221551  0.372581  0.134815
# 4    0.942015  0.357449  0.472451  0.085514  0.155223
# 5    0.599654  0.069481  0.838729  0.172616  0.221483
# 6    0.700728  0.100798  0.435555  0.384188  0.770515
# ..        ...       ...       ...       ...       ...
# 329  0.445246  0.205417  0.320015  0.162270  0.414028
# 330  0.409597  0.743952  0.571884  0.646609  0.290460
# 331  0.632856  0.767467  0.378673  0.507562  0.432620
# 332  0.382705  0.039203  0.604431  0.775401  0.812413
# 333  0.824661  0.579149  0.701643  0.175579  0.088738
#
# [330 rows x 5 columns]

# %%
newdf.reset_index(drop=True) #drop removes the extra column of old indexing
# Out:
#             A         B         C         D         E
# 0         666  0.519559  0.912975  0.534882  0.343862
# 1    0.119814  0.589312  0.221551  0.372581  0.134815
# 2    0.942015  0.357449  0.472451  0.085514  0.155223
# 3    0.599654  0.069481  0.838729  0.172616  0.221483
# 4    0.700728  0.100798  0.435555  0.384188  0.770515
# ..        ...       ...       ...       ...       ...
# 325  0.445246  0.205417  0.320015  0.162270  0.414028
# 326  0.409597  0.743952  0.571884  0.646609  0.290460
# 327  0.632856  0.767467  0.378673  0.507562  0.432620
# 328  0.382705  0.039203  0.604431  0.775401  0.812413
# 329  0.824661  0.579149  0.701643  0.175579  0.088738
#
# [330 rows x 5 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         666  0.519559  0.912975  0.534882  0.343862
# 1    0.119814  0.589312  0.221551  0.372581  0.134815
# 2    0.942015  0.357449  0.472451  0.085514  0.155223
# 3    0.599654  0.069481  0.838729  0.172616  0.221483
# 4    0.700728  0.100798  0.435555  0.384188  0.770515
# ..        ...       ...       ...       ...       ...
# 325  0.445246  0.205417  0.320015  0.162270  0.414028
# 326  0.409597  0.743952  0.571884  0.646609  0.290460
# 327  0.632856  0.767467  0.378673  0.507562  0.432620
# 328  0.382705  0.039203  0.604431  0.775401  0.812413
# 329  0.824661  0.579149  0.701643  0.175579  0.088738
#
# [330 rows x 5 columns]

# %%
pd.DataFrame.drop_duplicates(newdf)
# Out:
#             A         B         C         D         E
# 0         666  0.519559  0.912975  0.534882  0.343862
# 1    0.119814  0.589312  0.221551  0.372581  0.134815
# 2    0.942015  0.357449  0.472451  0.085514  0.155223
# 3    0.599654  0.069481  0.838729  0.172616  0.221483
# 4    0.700728  0.100798  0.435555  0.384188  0.770515
# ..        ...       ...       ...       ...       ...
# 325  0.445246  0.205417  0.320015  0.162270  0.414028
# 326  0.409597  0.743952  0.571884  0.646609  0.290460
# 327  0.632856  0.767467  0.378673  0.507562  0.432620
# 328  0.382705  0.039203  0.604431  0.775401  0.812413
# 329  0.824661  0.579149  0.701643  0.175579  0.088738
#
# [330 rows x 5 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# Name: B, Length: 330, dtype: bool

# %%
newdf['B']=None #appropriate way is newdf.loc[:,['B']]=None

# %%
newdf.loc[:,['E']]=None

# %%
newdf
# Out:
#             A     B         C         D     E
# 0         666  None  0.912975  0.534882  None
# 1    0.119814  None  0.221551  0.372581  None
# 2    0.942015  None  0.472451  0.085514  None
# 3    0.599654  None  0.838729  0.172616  None
# 4    0.700728  None  0.435555  0.384188  None
# ..        ...   ...       ...       ...   ...
# 325  0.445246  None  0.320015  0.162270  None
# 326  0.409597  None  0.571884  0.646609  None
# 327  0.632856  None  0.378673  0.507562  None
# 328  0.382705  None  0.604431  0.775401  None
# 329  0.824661  None  0.701643  0.175579  None
#
# [330 rows x 5 columns]

# %%
newdf['E'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 325    True
# 326    True
# 327    True
# 328    True
# 329    True
# Name: E, Length: 330, dtype: bool

# %%
import pandas as pd
import numpy as np

df13 = pd.DataFrame({ "name":['venu','bhoma','aishu'],
                     "toy":[np.nan,'buddy','guddy'],
                     "born":[pd.NaT,pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df13.head()
# Out:
#     name    toy       born
# 0   venu    NaN        NaT
# 1  bhoma  buddy 1940-04-25
# 2  aishu  guddy        NaT

# %%
df13.dropna()
# Out:
#     name    toy       born
# 1  bhoma  buddy 1940-04-25

# %%
df13.dropna(how='all') #till all the values in rows are na it should not drop the values.
# Out:
#     name    toy       born
# 0   venu    NaN        NaT
# 1  bhoma  buddy 1940-04-25
# 2  aishu  guddy        NaT

# %%
import pandas as pd
import numpy as np

df23 = pd.DataFrame({ "name":['venu','bhoma','aishu'],
                     "toy":[np.nan,np.nan,np.nan],
                     "born":[pd.NaT,pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df23.head()
# Out:
#     name  toy       born
# 0   venu  NaN        NaT
# 1  bhoma  NaN 1940-04-25
# 2  aishu  NaN        NaT

# %%
df23.dropna(how='all',axis=1)
# Out:
#     name       born
# 0   venu        NaT
# 1  bhoma 1940-04-25
# 2  aishu        NaT

# %%
import pandas as pd
import numpy as np

df33 = pd.DataFrame({ "name":['venu','bhoma','venu'],
                     "toy":[np.nan,np.nan,np.nan],
                     "born":[pd.NaT,pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df33.head()
# Out:
#     name  toy       born
# 0   venu  NaN        NaT
# 1  bhoma  NaN 1940-04-25
# 2   venu  NaN        NaT

# %%
df33.drop_duplicates()
# Out:
#     name  toy       born
# 0   venu  NaN        NaT
# 1  bhoma  NaN 1940-04-25

# %%
df33.drop_duplicates(subset=['name'])
# Out:
#     name  toy       born
# 0   venu  NaN        NaT
# 1  bhoma  NaN 1940-04-25

# %%
df33.drop_duplicates(subset=['name'],keep='first')
# Out:
#     name  toy       born
# 0   venu  NaN        NaT
# 1  bhoma  NaN 1940-04-25

# %%
df33.drop_duplicates(subset=['name'],keep='last')
# Out:
#     name  toy       born
# 1  bhoma  NaN 1940-04-25
# 2   venu  NaN        NaT

# %%
df33.drop_duplicates(subset=['name'],keep=False)
# Out:
#     name  toy       born
# 1  bhoma  NaN 1940-04-25

# %%
df33.shape
# Out:
# (3, 3)

# %%
df33.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     0 non-null      float64
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 200.0+ bytes

# %%
df33['name'].value_counts(dropna=False)
# Out:
# venu     2
# bhoma    1
# Name: name, dtype: int64

# %%
df33.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True  False   True
# 2  True  False  False

# %%
df33.isnull()
# Out:
#     name   toy   born
# 0  False  True   True
# 1  False  True  False
# 2  False  True   True

# %%
#create a dataframe which contains only integers with 3 rows and 2 columns.
#run following dataframe methods on them:
df.describe()
df.mean()
df.corr()
df.count()
df.max()
df.min()
df.median()
df.std()

# %%
import pandas as pd
import numpy as np

bv = pd.DataFrame(np.random.randint(0,100,(3,2)),index=np.arange(3))

# %%
bv
# Out:
#     0   1
# 0  37  48
# 1  95  11
# 2  79  74

# %%
bv.describe()
# Out:
#                0          1
# count   3.000000   3.000000
# mean   70.333333  44.333333
# std    29.955523  31.659648
# min    37.000000  11.000000
# 25%    58.000000  29.500000
# 50%    79.000000  48.000000
# 75%    87.000000  61.000000
# max    95.000000  74.000000

# %%
bv.mean()  #bv.mean(axis=1)
# Out:
# 0    70.333333
# 1    44.333333
# dtype: float64

# %%
bv.max()  #bv.max(axis=1)
# Out:
# 0    95
# 1    74
# dtype: int32

# %%
bv.min()  #bv.min(axis=1)
# Out:
# 0    37
# 1    11
# dtype: int32

# %%
bv.std()  #bv.std(axis=1)
# Out:
# 0    29.955523
# 1    31.659648
# dtype: float64

# %%
bv.median()
# Out:
# 0    79.0
# 1    48.0
# dtype: float64

# %%
bv.corr()
# Out:
#           0         1
# 0  1.000000 -0.362372
# 1 -0.362372  1.000000

# %%
bv.count()
# Out:
# 0    3
# 1    3
# dtype: int64
